# %% [markdown]
# # Medium

# %% [markdown]
# ## Databricks
#
# https://medium.com/dbsql-sme-engineering/deduplicating-data-on-the-databricks-lakehouse-5-ways-36a80987c716
#
# https://nidhig631.medium.com/did-you-notice-this-in-databricks-a-new-way-to-govern-connect-create-and-share-9bdbc22aebb1
#
# https://medium.com/towards-data-engineering/how-i-cut-my-spark-job-runtime-by-70-without-adding-more-clusters-64e6e0f8dd31

# %% [markdown]
# ## PySpark
# https://medium.com/@sriwworldofcoding/mastering-explode-in-pyspark-handle-nested-arrays-like-a-pro-2365c4cc1253

# %% [markdown]
# ## Business
#
# https://medium.com/codex/retail-analytics-top-16-concepts-every-data-professional-should-know-ee0aa84108e2

# %% [markdown]
# ## SQL
#
# https://towardsdev.com/top-10-advanced-sql-queries-d4b2ddca51de

# %% [markdown]
# ## Python
#
# https://medium.datadriveninvestor.com/powerful-one-liners-in-pandas-every-data-scientist-should-know-620a84c14408
#
# https://python.plainenglish.io/27-python-coding-tips-lessons-i-wish-i-knew-when-i-started-coding-1608696b3b0d
#
# https://medium.com/gdsc-babcock-dataverse/20-of-eda-plots-data-scientists-use-80-of-the-time-abe7b2ff5cc2

# %% [markdown]
# # Youtube

# %% [markdown]
# ## Databircks news
#
# https://www.youtube.com/@databricks_hubert_dudek
